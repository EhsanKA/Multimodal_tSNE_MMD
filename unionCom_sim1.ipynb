# %%
# !ls UnionCom-master/simu1/
# Out:
# data1.txt   data2.txt   domain1.txt domain2.txt type1.txt   type2.txt

# %%
import numpy as np

data1 = np.loadtxt("UnionCom-master/simu1/domain1.txt")
data2 = np.loadtxt("UnionCom-master/simu1/domain2.txt")
type1 = np.loadtxt("UnionCom-master/simu1/type1.txt")
type2 = np.loadtxt("UnionCom-master/simu1/type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
# Out:
# <ipython-input-15-3fc59445f3b3>:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   type1 = type1.astype(np.int)
# <ipython-input-15-3fc59445f3b3>:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   type2 = type2.astype(np.int)

# %%
from tsne_mmd import *

# %%
X1, X2 = data1, data2
timepoint1, timepoint2 = type1.reshape((type1.shape[0],1)), type2.reshape((type2.shape[0],1))

# %%
n_repeat = 1
ts1_list, ts2_list ,time_list = generate_results(X1, X2, n_repeat, no_dims=10, perplexity=100, max_iter=1000)
# Out:
# ********** replication:1 ********
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 300...
# Mean value of sigma: 16.986754
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 300...
# Mean value of sigma: 12.196233
# Iteration 10: error is 7.885926
# Iteration 10: error is 7.759332
# Iteration 20: error is 8.122094
# Iteration 20: error is 8.138631
# Iteration 30: error is 9.189525
# Iteration 30: error is 8.893511
# Iteration 40: error is 8.404237
# Iteration 40: error is 8.290577
# Iteration 50: error is 8.323250
# Iteration 50: error is 8.271840
# Iteration 60: error is 8.242200
# Iteration 60: error is 8.404366
# Iteration 70: error is 8.257314
# Iteration 70: error is 8.350826
# Iteration 80: error is 8.150856
# Iteration 80: error is 8.219181
# Iteration 90: error is 8.091646
# Iteration 90: error is 8.155850
# Iteration 100: error is 8.140286
# Iteration 100: error is 8.207829
# Iteration 110: error is 0.287023
# Iteration 110: error is 0.245336
# Iteration 120: error is 0.131522
# Iteration 120: error is 0.104701
# Iteration 130: error is 0.085861
# Iteration 130: error is 0.072506
# Iteration 140: error is 0.068382
# Iteration 140: error is 0.066171
# Iteration 150: error is 0.063927
# Iteration 150: error is 0.064211
# Iteration 160: error is 0.062555
# Iteration 160: error is 0.063148
# Iteration 170: error is 0.061752
# Iteration 170: error is 0.062497
# Iteration 180: error is 0.061279
# Iteration 180: error is 0.062142
# Iteration 190: error is 0.060998
# Iteration 190: error is 0.061949
# Iteration 200: error is 0.060819
# Iteration 200: error is 0.061820
# Iteration 210: error is 0.060689
# Iteration 210: error is 0.061713
# Iteration 220: error is 0.060570
# Iteration 220: error is 0.061608
# Iteration 230: error is 0.060446
# Iteration 230: error is 0.061509
# Iteration 240: error is 0.060320
# Iteration 240: error is 0.061418
# Iteration 250: error is 0.060193
# Iteration 250: error is 0.061338
# Iteration 260: error is 0.060086
# Iteration 260: error is 0.061281
# Iteration 270: error is 0.059992
# Iteration 270: error is 0.061246
# Iteration 280: error is 0.059922
# Iteration 280: error is 0.061221
# Iteration 290: error is 0.059877
# Iteration 290: error is 0.061203
# Iteration 300: error is 0.059841
# Iteration 760: error is 0.061163
# Iteration 770: error is 0.059764
# Iteration 770: error is 0.061163
# Iteration 780: error is 0.059764
# Iteration 780: error is 0.061163
# Iteration 790: error is 0.059764
# Iteration 790: error is 0.061163
# Iteration 800: error is 0.059764
# Iteration 800: error is 0.061163
# Iteration 810: error is 0.059764
# Iteration 810: error is 0.061163
# Iteration 820: error is 0.059763
# Iteration 820: error is 0.061163
# Iteration 830: error is 0.059763
# Iteration 830: error is 0.061162
# Iteration 840: error is 0.059763
# Iteration 840: error is 0.061162
# Iteration 850: error is 0.059763
# Iteration 850: error is 0.061162
# Iteration 860: error is 0.059763
# Iteration 860: error is 0.061162
# Iteration 870: error is 0.059763
# Iteration 870: error is 0.061162
# Iteration 880: error is 0.059763
# Iteration 880: error is 0.061162
# Iteration 890: error is 0.059763
# Iteration 890: error is 0.061162
# Iteration 900: error is 0.059763
# Iteration 900: error is 0.061162
# Iteration 910: error is 0.059763
# Iteration 910: error is 0.061162
# Iteration 920: error is 0.059763
# Iteration 920: error is 0.061162
# Iteration 930: error is 0.059763
# Iteration 930: error is 0.061162
# Iteration 940: error is 0.059763
# Iteration 940: error is 0.061161
# Iteration 950: error is 0.059763
# Iteration 950: error is 0.061161
# Iteration 960: error is 0.059763
# Iteration 960: error is 0.061161
# Iteration 970: error is 0.059763
# Iteration 970: error is 0.061161
# Iteration 980: error is 0.059763
# Iteration 980: error is 0.061161
# Iteration 990: error is 0.059763
# Iteration 990: error is 0.061161
# Iteration 1000: error is 0.059763
# Iteration 1000: error is 0.061161
# Preprocessing the data using PCA...
# Preprocessing the data using PCA...
# ********** run time is:38.149210691452026 ********

# %%
import matplotlib.pyplot as plt 
import pylab
def final_embedding_plot(ts1, ts2, c1, c2):
    '''
    plotting 2D embeddings for each of two data-sets besides each other
    
    parameters
    ----------
    ts1 : an object of TSNE class
    ts2 : an object of TSNE class
    c1 : related labels to ts1 data-set
    c2 : related labels to ts2 data-set
        
    '''
    plt.figure(figsize=(30, 10), dpi=80)  # create a plot figure
    
    x1, x2 = ts1.y2d, ts2.y2d

    plt.subplot(1, 2, 1) # (rows, columns, panel number)
    plt.scatter(x1[:, 0], x1[:, 1], 20, c1)
    plt.subplot(1, 2, 2) # (rows, columns, panel number)
    plt.scatter(x2[:, 0], x2[:, 1], 20, c2)


def plot_togather(ts1, ts2, c1, c2):
        
    x1, x2 = ts1.y2d, ts2.y2d

    ax = pylab.subplot(111)
    ax.scatter(x1[:, 0], x1[:, 1], 20, c1)
    ax.scatter(x2[:, 0], x2[:, 1], 20, c2)
    qqqq = ax.figure.show()

# %%
ts1 = ts1_list[0]
ts2 = ts2_list[0]
final_embedding_plot(ts1_list[0], ts2_list[0], timepoint1, timepoint2)

# %%
plot_togather(ts1_list[0], ts2_list[0], timepoint1, timepoint2)
# Out:
# <ipython-input-55-e0c76296abbf>:32: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   qqqq = ax.figure.show()
